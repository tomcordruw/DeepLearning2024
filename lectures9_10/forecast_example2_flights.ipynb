# %% [markdown]
# <b>Forecasting experimentation 2 - Flight passenger data</b>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import keras
from keras.callbacks import ModelCheckpoint
# Out:
# WARNING:tensorflow:From c:\Users\tomco\Desktop\Various Things\Engineering Study\Semester Spring 2024\Deep Learning\DeepLearning2024\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = sns.load_dataset("flights")

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# <b>Before going further, we have to scale the passengers-value to be between 0 and 1</b>

# %%
scaler = MinMaxScaler()
df[["passengers"]] = scaler.fit_transform(df[["passengers"]])
df.index = df.index * 0.1 + 1

# %%
df
# Out:
#       year month  passengers
# 1.0   1949   Jan    0.015444
# 1.1   1949   Feb    0.027027
# 1.2   1949   Mar    0.054054
# 1.3   1949   Apr    0.048263
# 1.4   1949   May    0.032819
# ...    ...   ...         ...
# 14.9  1960   Aug    0.969112
# 15.0  1960   Sep    0.779923
# 15.1  1960   Oct    0.689189
# 15.2  1960   Nov    0.552124
# 15.3  1960   Dec    0.633205
#
# [144 rows x 3 columns]

# %% [markdown]
# <b>X_train, y_train, X_test, y_test</b>

# %%
# let's figure out a proper cutoff point
# for train/test-split
cutoff = int(len(df) * 0.67)

X_train = df.index[0:cutoff]
y_train = df["passengers"].iloc[0:cutoff]

# test data
X_test = df.index[cutoff:]
y_test = df["passengers"].iloc[cutoff:]

# convert to NumPy array-format (expected by the generators)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

n_features = 1

# Note to self: is this necessary?
train_series = y_train.reshape((len(y_train), n_features))
test_series = y_test.reshape((len(y_test), n_features))

# %%
# plot the original train + test data
# see the cutoff point
fig, ax = plt.subplots(1, 1, figsize=(15, 4))
ax.plot(X_train,y_train, lw=1, label='train data')
ax.plot(X_test, y_test,  lw=1, label='test data')
ax.legend(loc="upper left")
plt.show()

# %%
# TimeseriesGenerators, for train and test
from keras.preprocessing.sequence import TimeseriesGenerator

# this is the timestep size
# so if we have 1000 points, and look_back is 20 => 50 time steps
look_back  = 12

# using 1 => using time steps
# anything above 1 => windowing (instead of time steps)
window_size = 1

# the amount of data fed into the neural network while training
# the bigger it is, the faster the training
# but with forecasts it also affects the performance
batch_size = 1

train_generator = TimeseriesGenerator(train_series, train_series,
                                      length        = look_back, 
                                      #sampling_rate = 1,
                                      stride        = window_size,
                                      batch_size    = batch_size)

test_generator = TimeseriesGenerator(test_series, test_series,
                                      length        = look_back, 
                                      #sampling_rate = 1,
                                      stride        = window_size,
                                      batch_size    = batch_size)

# %%
from keras.models import Sequential
from keras.layers import Dense

# rule of thumb: RNN is usually good with short-term trends
# while LSTM is usually good with long-term trends
# effectiveness depends on the situation/dataset
from keras.layers import LSTM
from keras.layers import SimpleRNN

# make a simple LSTM/RNN network
# number of neurons can be adjusted
model = Sequential()

#model.add(LSTM(64, activation="relu", input_shape=(look_back, n_features)))
model.add(SimpleRNN(128, activation="relu",input_shape=(look_back, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

callbacks = [
    ModelCheckpoint("best_model_flights.keras", monitor='val_loss', mode='min', save_best_only=True)
]

# start training the model, use also validation data for metrics later
model.fit(train_generator,epochs=150, callbacks=callbacks, verbose=1, validation_data=test_generator)
# Out:
# WARNING:tensorflow:From c:\Users\tomco\Desktop\Various Things\Engineering Study\Semester Spring 2024\Deep Learning\DeepLearning2024\.venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\tomco\Desktop\Various Things\Engineering Study\Semester Spring 2024\Deep Learning\DeepLearning2024\.venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/150
# WARNING:tensorflow:From c:\Users\tomco\Desktop\Various Things\Engineering Study\Semester Spring 2024\Deep Learning\DeepLearning2024\.venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 84/84 [==============================] - 2s 8ms/step - loss: 0.0076 - val_loss: 0.0228
# Epoch 2/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0150
# Epoch 3/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 0.0169
# Epoch 4/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 0.0096
# Epoch 5/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0030 - val_loss: 0.0106
# Epoch 6/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0033 - val_loss: 0.0149
# Epoch 7/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0036 - val_loss: 0.0221
# Epoch 8/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0119
# Epoch 9/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0107
# Epoch 10/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0102
# Epoch 11/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.0091
# Epoch 12/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.0141
# Epoch 13/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 0.0110
# Epoch 14/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0116
# Epoch 15/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.0095
# Epoch 16/150
# 84/84 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0074
# Epoch 17/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 18/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0089
# Epoch 19/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0126
# Epoch 20/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0060
# Epoch 21/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0224
# Epoch 22/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0029 - val_loss: 0.0137
# Epoch 23/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 0.0103
# Epoch 24/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0116
# Epoch 25/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0019 - val_loss: 0.0077
# Epoch 26/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0079
# Epoch 27/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0047
# Epoch 28/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0064
# Epoch 29/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0056
# Epoch 30/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0046
# Epoch 31/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0065
# Epoch 32/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0048
# Epoch 33/150
# 84/84 [==============================] - 0s 5ms/step - loss: 6.0860e-04 - val_loss: 0.0078
# Epoch 34/150
# 84/84 [==============================] - 0s 5ms/step - loss: 8.7361e-04 - val_loss: 0.0160
# Epoch 35/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0261
# Epoch 36/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0075
# Epoch 37/150
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0071
# Epoch 38/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0067
# Epoch 39/150
# 84/84 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0048
# Epoch 40/150
# 84/84 [==============================] - 0s 5ms/step - loss: 9.8205e-04 - val_loss: 0.0032
# Epoch 41/150
# 84/84 [==============================] - 0s 5ms/step - loss: 8.5009e-04 - val_loss: 0.0038
# Epoch 42/150
# 84/84 [==============================] - 0s 5ms/step - loss: 8.7136e-04 - val_loss: 0.0045
# Epoch 43/150
# 84/84 [==============================] - 0s 5ms/step - loss: 5.7781e-04 - val_loss: 0.0046
# Epoch 44/150
# 84/84 [==============================] - 0s 5ms/step - loss: 5.1867e-04 - val_loss: 0.0038
# Epoch 45/150
# 84/84 [==============================] - 0s 5ms/step - loss: 6.9404e-04 - val_loss: 0.0038
150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.2564e-04 - val_loss: 0.0035
# Epoch 118/150
# 84/84 [==============================] - 0s 4ms/step - loss: 5.4673e-04 - val_loss: 0.0031
# Epoch 119/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.2721e-04 - val_loss: 0.0032
# Epoch 120/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.6442e-04 - val_loss: 0.0026
# Epoch 121/150
# 84/84 [==============================] - 0s 4ms/step - loss: 3.2148e-04 - val_loss: 0.0020
# Epoch 122/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.7383e-04 - val_loss: 0.0036
# Epoch 123/150
# 84/84 [==============================] - 0s 5ms/step - loss: 1.9261e-04 - val_loss: 0.0032
# Epoch 124/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.5657e-04 - val_loss: 0.0022
# Epoch 125/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.1973e-04 - val_loss: 0.0036
# Epoch 126/150
# 84/84 [==============================] - 0s 4ms/step - loss: 8.6744e-05 - val_loss: 0.0018
# Epoch 127/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.2897e-04 - val_loss: 0.0035
# Epoch 128/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.2065e-04 - val_loss: 0.0041
# Epoch 129/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.2364e-04 - val_loss: 0.0034
# Epoch 130/150
# 84/84 [==============================] - 0s 5ms/step - loss: 7.0384e-05 - val_loss: 0.0043
# Epoch 131/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.0866e-04 - val_loss: 0.0035
# Epoch 132/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.8308e-04 - val_loss: 0.0019
# Epoch 133/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.3999e-04 - val_loss: 0.0065
# Epoch 134/150
# 84/84 [==============================] - 0s 5ms/step - loss: 1.6475e-04 - val_loss: 0.0029
# Epoch 135/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.3252e-04 - val_loss: 0.0028
# Epoch 136/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.4074e-04 - val_loss: 0.0046
# Epoch 137/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.5283e-04 - val_loss: 0.0037
# Epoch 138/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.7657e-04 - val_loss: 0.0030
# Epoch 139/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.0137e-04 - val_loss: 0.0020
# Epoch 140/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.2145e-04 - val_loss: 0.0049
# Epoch 141/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.9523e-04 - val_loss: 0.0044
# Epoch 142/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.1349e-04 - val_loss: 0.0028
# Epoch 143/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.0233e-04 - val_loss: 0.0030
# Epoch 144/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.1945e-04 - val_loss: 0.0021
# Epoch 145/150
# 84/84 [==============================] - 0s 4ms/step - loss: 5.3322e-04 - val_loss: 0.0026
# Epoch 146/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.0538e-04 - val_loss: 0.0077
# Epoch 147/150
# 84/84 [==============================] - 0s 4ms/step - loss: 3.9123e-04 - val_loss: 0.0033
# Epoch 148/150
# 84/84 [==============================] - 0s 4ms/step - loss: 2.4635e-04 - val_loss: 0.0028
# Epoch 149/150
# 84/84 [==============================] - 0s 4ms/step - loss: 1.1475e-04 - val_loss: 0.0020
# Epoch 150/150
# 84/84 [==============================] - 0s 4ms/step - loss: 6.8163e-05 - val_loss: 0.0019

# %%
# training metrics
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <Axes: >

# %%
# load the best model from the model checkpoint
model = keras.models.load_model("best_model_flights.keras")

# %%
# Create test predictions
test_predictions  = model.predict(test_generator)
# Out:
# 36/36 [==============================] - 0s 2ms/step

# %%
# this code is not optimal
# our code should instead scale based on the X_train / X_test
x1 = np.arange(0,len(y_train))
x2 = np.arange(len(y_train),len(y_train) + len(y_test))
x3 = np.arange(len(y_train) + look_back, len(y_train) + len(y_test))

fig, ax = plt.subplots(1, 1, figsize=(10, 3))

# we can also hide the trianing data to inspect the 
# predictions vs. test data separately
#ax.plot(x1,y_train, lw=1, label='train data')
ax.plot(x2,y_test, lw=1, c='y', label='test data')
ax.plot(x3,test_predictions, lw=1, c='r', label='predictions')
ax.legend(loc="lower left")
plt.show()

# %%
 # TF evaluation metrics
result = model.evaluate(train_generator)
print(f"Training loss: {result}")

# test loss
result = model.evaluate(test_generator)
print(f"Testing loss: {result}")

# these values are very close
# which means our model is quite optimal (on paper!)
# Out:
# 84/84 [==============================] - 0s 3ms/step - loss: 6.7907e-05
# Training loss: 6.790691986680031e-05
# 36/36 [==============================] - 0s 2ms/step - loss: 0.0018
# Testing loss: 0.0018145684152841568

# %%
# make a separate copy of the test values
# that matches with y_test
actual_y_test = np.concatenate([y for x, y in test_generator])
errors = np.abs(actual_y_test - test_predictions)
mape = np.mean(errors / actual_y_test) * 100

# print out MAPE-score
print("MAPE (mean average precision error):")
print(f"{round(mape, 2)} %")

# the typical error metrics
# MAE - Mean average error
# MAPE score => less than 10% => excellent result
# MAPE score => 10-20 % => good result
# MAPE score => 20-50% => okay / reasonable / decent result
# negative MAPE score => the model constantly overestimates the values
# MAPE score over 100% => the model constantly underestimates the values
# it's possible to get a weird MAPE result with synthetic test data
# because the data is so predicatble
print("\nMAE")
print(round(metrics.mean_absolute_error(actual_y_test , test_predictions), 2), " units")

# MSE - Mean square error
print("\nMSE")
print(round(metrics.mean_squared_error(actual_y_test, test_predictions), 2), " units^2")

# RMSE - Root mean square error
print('\nRMSE:')
print(round(np.sqrt(metrics.mean_squared_error(actual_y_test , test_predictions)), 2), " units")

# R-squared. 0 = the model descibes the dataset poorly
# 1 = model describes the dataset perfectly
print('\nR-squared:')
print(round(metrics.r2_score(actual_y_test , test_predictions), 2))
# Out:
# MAPE (mean average precision error):
# 5.21 %
#
# MAE
# 0.03  units
#
# MSE
# 0.0  units^2
#
# RMSE:
# 0.04  units
#
# R-squared:
# 0.92

# %%
# EXTRAPOLATION TEST 
extrapolation = list()
seed_batch    = y_test[:look_back].reshape((1,look_back, n_features))
current_batch = seed_batch

# extrapolate the next n values
n = 80
for i in range(n):
    predicted_value = model.predict(current_batch)[0]
    extrapolation.append(predicted_value) 
    current_batch = np.append(current_batch[:,1:,:],[[predicted_value]],axis=1)
# Out:
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
# Plotting the train/test data and overlaying the extrapolated data
x1 = np.arange(0, len(y_train))
x2 = np.arange(len(y_train), len(y_train) + len(y_test))
x3 = np.arange(len(y_train) + look_back, len(y_train) + len(extrapolation) + look_back)

fig, ax = plt.subplots(1, 1, figsize=(10, 3))

# we can also hide the training data to inspect the
# the predictions vs. test data separately
ax.plot(x1, y_train, lw=1, label='train data')
ax.plot(x2, y_test, lw=1, c='y', label='test data')
ax.plot(x3, extrapolation, lw=1, c='r', label='predictions')
ax.legend(loc="upper left")
plt.show()
