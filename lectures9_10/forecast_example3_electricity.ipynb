# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import keras
from keras.callbacks import ModelCheckpoint

# %%
df = pd.read_csv("Electric_Production.csv")
df = df.drop("DATE", axis=1)

# %%
 # save the name of target column, to make things easier
target_col = "IPG2211A2N"

# %%
# let's scale the values with MinMaxScaler, so that we don't
# affect the distribution of data (thus making the signal not be realistic anymore)
# MinMaxScaler is a good solution here
scaler = MinMaxScaler()
df[[target_col]] = scaler.fit_transform(df[[target_col]])
df.index = df.index * 0.1 + 1

# %%
df
# Out:
#       IPG2211A2N
# 1.0     0.232017
# 1.1     0.207274
# 1.2     0.096304
# 1.3     0.029104
# 1.4     0.000000
# ...          ...
# 40.2    0.584431
# 40.3    0.516922
# 40.4    0.567161
# 40.5    0.801813
# 40.6    1.000000
#
# [397 rows x 1 columns]

# %%
# let's figure out a proper cutoff point
# for train/test-split
cutoff = int(len(df) * 0.80)

X_train = df.index[0:cutoff]
y_train = df[target_col].iloc[0:cutoff]

# test data
X_test = df.index[cutoff:]
y_test = df[target_col].iloc[cutoff:]

# convert to NumPy array-format (expected by the generators)
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

n_features = 1

# Note to self: is this necessary?
train_series = y_train.reshape((len(y_train), n_features))
test_series = y_test.reshape((len(y_test), n_features))

# %%
# plot the original train + test data
# see the cutoff point
fig, ax = plt.subplots(1, 1, figsize=(14, 6))
ax.plot(X_train,y_train, lw=1, label='train data')
ax.plot(X_test, y_test,  lw=1, label='test data')
ax.legend(loc="upper left")
plt.show()

# %%
# TimeseriesGenerators, for train and test
from keras.preprocessing.sequence import TimeseriesGenerator

# this is the timestep size
# so if we have 1000 points, and look_back is 20 => 50 time steps
look_back  = 16

# using 1 => using time steps
# anything above 1 => windowing (instead of time steps)
window_size = 1

# the amount of data fed into the neural network while training
# the bigger it is, the faster the training
# but with forecasts it also affects the performance
batch_size = 1

train_generator = TimeseriesGenerator(train_series, train_series,
                                      length        = look_back, 
                                      #sampling_rate = 1,
                                      stride        = window_size,
                                      batch_size    = batch_size)

test_generator = TimeseriesGenerator(test_series, test_series,
                                      length        = look_back, 
                                      #sampling_rate = 1,
                                      stride        = window_size,
                                      batch_size    = batch_size)

# %%
from keras.models import Sequential
from keras.layers import Dense

# rule of thumb: RNN is usually good with short-term trends
# while LSTM is usually good with long-term trends
# effectiveness depends on the situation/dataset
from keras.layers import LSTM
from keras.layers import SimpleRNN

# make a simple LSTM/RNN network
# number of neurons can be adjusted
model = Sequential()

model.add(LSTM(64, activation="relu", input_shape=(look_back, n_features)))
#model.add(SimpleRNN(32, activation="relu",input_shape=(look_back, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

callbacks = [
    ModelCheckpoint("best_model_electricity.keras", monitor='val_loss', mode='min', save_best_only=True)
]

# start training the model, use also validation data for metrics later
model.fit(train_generator,epochs=150, callbacks=callbacks, verbose=1, validation_data=test_generator)
# Out:
# Epoch 1/150
# 305/305 [==============================] - 3s 6ms/step - loss: 0.0222 - val_loss: 0.0242
# Epoch 2/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0124 - val_loss: 0.0362
# Epoch 3/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0114 - val_loss: 0.0151
# Epoch 4/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0092 - val_loss: 0.0180
# Epoch 5/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 6/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.0092
# Epoch 7/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0033 - val_loss: 0.0054
# Epoch 8/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0027 - val_loss: 0.0049
# Epoch 9/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0023 - val_loss: 0.0052
# Epoch 10/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0019 - val_loss: 0.0036
# Epoch 11/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 12/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0021 - val_loss: 0.0058
# Epoch 13/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 14/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 15/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 16/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 17/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 18/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 19/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0061
# Epoch 20/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 21/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 22/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 0.0047
# Epoch 23/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 24/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 25/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0054
# Epoch 26/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 27/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 28/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 29/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 30/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 31/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 0.0052
# Epoch 32/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 33/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 34/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 35/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0081
# Epoch 36/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 37/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0047
# Epoch 38/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 39/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 40/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 41/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 42/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 43/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 44/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 45/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 46/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 47/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 48/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 49/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 50/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 51/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 52/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 53/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 54/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 55/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 56/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 57/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 58/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 59/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 60/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 61/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 62/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 63/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 64/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 65/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 66/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 67/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 68/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 69/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 70/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 71/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 72/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 73/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 74/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 75/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 76/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 77/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0012 - val_loss: 0.0072
# Epoch 78/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 79/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 80/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 81/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 82/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 83/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 84/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 85/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 86/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0040
# Epoch 87/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0038
# Epoch 88/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 89/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 90/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 91/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 92/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 93/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 94/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 95/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 96/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0035
# Epoch 97/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 98/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0047
# Epoch 99/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 100/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 101/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 102/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 103/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 104/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 105/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 106/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 107/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 108/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 109/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 110/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 111/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 112/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 113/150
# 305/305 [==============================] - 2s 6ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 114/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0010 - val_loss: 0.0031
# Epoch 115/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 116/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0037
# Epoch 117/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 118/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 119/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 120/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0040
# Epoch 121/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 122/150
# 305/305 [==============================] - 1s 4ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 123/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 124/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 125/150
# 305/305 [==============================] - 2s 5ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 126/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0010 - val_loss: 0.0030
# Epoch 127/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 128/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0012 - val_loss: 0.0033
# Epoch 129/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0010 - val_loss: 0.0031
# Epoch 130/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 131/150
# 305/305 [==============================] - 1s 4ms/step - loss: 0.0010 - val_loss: 0.0031
# Epoch 132/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 133/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 134/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 135/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0010 - val_loss: 0.0032
# Epoch 136/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 137/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 138/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 139/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 140/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 141/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 142/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 143/150
# 305/305 [==============================] - 1s 5ms/step - loss: 9.9410e-04 - val_loss: 0.0030
# Epoch 144/150
# 305/305 [==============================] - 1s 5ms/step - loss: 9.7538e-04 - val_loss: 0.0031
# Epoch 145/150
# 305/305 [==============================] - 1s 4ms/step - loss: 9.9221e-04 - val_loss: 0.0031
# Epoch 146/150
# 305/305 [==============================] - 1s 5ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 147/150
# 305/305 [==============================] - 1s 5ms/step - loss: 9.3628e-04 - val_loss: 0.0030
# Epoch 148/150
# 305/305 [==============================] - 1s 5ms/step - loss: 9.8164e-04 - val_loss: 0.0029
# Epoch 149/150
# 305/305 [==============================] - 1s 5ms/step - loss: 9.7348e-04 - val_loss: 0.0029
# Epoch 150/150
# 305/305 [==============================] - 1s 5ms/step - loss: 9.6549e-04 - val_loss: 0.0038

# %%
# training metrics
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <Axes: >

# %%
# load the best model from the model checkpoint
model = keras.models.load_model("best_model_electricity.keras")

# %%
# Create test predictions
test_predictions  = model.predict(test_generator)
# Out:
# 68/68 [==============================] - 0s 2ms/step

# %%
# this code is not optimal
# our code should instead scale based on the X_train / X_test
x1 = np.arange(0,len(y_train))
x2 = np.arange(len(y_train),len(y_train) + len(y_test))
x3 = np.arange(len(y_train) + look_back, len(y_train) + len(y_test))

fig, ax = plt.subplots(1, 1, figsize=(10, 3))

# we can also hide the trianing data to inspect the 
# predictions vs. test data separately
#ax.plot(x1,y_train, lw=1, label='train data')
ax.plot(x2,y_test, lw=1, c='y', label='test data')
ax.plot(x3,test_predictions, lw=1, c='r', label='predictions')
ax.legend(loc="lower left")
plt.show()

# %%
 # TF evaluation metrics
result = model.evaluate(train_generator)
print(f"Training loss: {result}")

# test loss
result = model.evaluate(test_generator)
print(f"Testing loss: {result}")

# these values are very close
# which means our model is quite optimal (on paper!)
# Out:
# 305/305 [==============================] - 1s 2ms/step - loss: 0.0012
# Training loss: 0.0011845948174595833
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0026
# Testing loss: 0.0025925214868038893

# %%
# make a separate copy of the test values
# that matches with y_test
actual_y_test = np.concatenate([y for x, y in test_generator])
errors = np.abs(actual_y_test - test_predictions)
mape = np.mean(errors / actual_y_test) * 100

# print out MAPE-score
print("MAPE (mean average precision error):")
print(f"{round(mape, 2)} %")

# the typical error metrics
# MAE - Mean average error
# MAPE score => less than 10% => excellent result
# MAPE score => 10-20 % => good result
# MAPE score => 20-50% => okay / reasonable / decent result
# negative MAPE score => the model constantly overestimates the values
# MAPE score over 100% => the model constantly underestimates the values
# it's possible to get a weird MAPE result with synthetic test data
# because the data is so predicatble
print("\nMAE")
print(round(metrics.mean_absolute_error(actual_y_test , test_predictions), 2), " units")

# MSE - Mean square error
print("\nMSE")
print(round(metrics.mean_squared_error(actual_y_test, test_predictions), 2), " units^2")

# RMSE - Root mean square error
print('\nRMSE:')
print(round(np.sqrt(metrics.mean_squared_error(actual_y_test , test_predictions)), 2), " units")

# R-squared. 0 = the model descibes the dataset poorly
# 1 = model describes the dataset perfectly
print('\nR-squared:')
print(round(metrics.r2_score(actual_y_test , test_predictions), 2))
# Out:
# MAPE (mean average precision error):
# 5.92 %
#
# MAE
# 0.04  units
#
# MSE
# 0.0  units^2
#
# RMSE:
# 0.05  units
#
# R-squared:
# 0.85

# %%
# EXTRAPOLATION TEST 
extrapolation = list()
seed_batch    = y_test[:look_back].reshape((1,look_back, n_features))
current_batch = seed_batch

# extrapolate the next n values
n = 140
for i in range(n):
    predicted_value = model.predict(current_batch)[0]
    extrapolation.append(predicted_value) 
    current_batch = np.append(current_batch[:,1:,:],[[predicted_value]],axis=1)
# Out:
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
# Plotting the train/test data and overlaying the extrapolated data
x1 = np.arange(0, len(y_train))
x2 = np.arange(len(y_train), len(y_train) + len(y_test))
x3 = np.arange(len(y_train) + look_back, len(y_train) + len(extrapolation) + look_back)

fig, ax = plt.subplots(1, 1, figsize=(10, 3))

# we can also hide the training data to inspect the
# the predictions vs. test data separately
ax.plot(x1, y_train, lw=1, label='train data')
ax.plot(x2, y_test, lw=1, c='y', label='test data')
ax.plot(x3, extrapolation, lw=1, c='r', label='predictions')
ax.legend(loc="upper left")
plt.show()
